# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/Attrition - Attrition.csv")

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df.groupby('EducationField').size()
# Out:
# EducationField
# Human Resources      27
# Life Sciences       606
# Marketing           159
# Medical             464
# Other                82
# Technical Degree    132
# dtype: int64

# %%
df.groupby('Attrition')['DailyRate'].count()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: DailyRate, dtype: int64

# %%
df.groupby('Attrition')['YearsSinceLastPromotion'].count()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: YearsSinceLastPromotion, dtype: int64

# %%
df.groupby('BusinessTravel').size()
# Out:
# BusinessTravel
# Non-Travel            150
# Travel_Frequently     277
# Travel_Rarely        1043
# dtype: int64

# %%
len(df[(df['Age'] > 20) & (df['Attrition'] == 'Yes')])
# Out:
# 221

# %%
len(df[(df['Age'] > 40) & (df['Department'] == 'Research & Development')])
# Out:
# 308

# %%
len(df[(df['Attrition'] == 'Yes') & (df['BusinessTravel'] == 'Travel_Rarely')])
# Out:
# 156

# %%
df[(df['Attrition'] =='Yes') & (df['Department'] == 'Research & Development')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 24     34       Yes      Travel_Rarely        699  Research & Development
# 26     32       Yes  Travel_Frequently       1125  Research & Development
# 34     24       Yes      Travel_Rarely        813  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1354   56       Yes      Travel_Rarely       1162  Research & Development
# 1375   32       Yes  Travel_Frequently        238  Research & Development
# 1390   28       Yes      Travel_Rarely       1404  Research & Development
# 1442   29       Yes      Travel_Rarely       1092  Research & Development
# 1444   56       Yes      Travel_Rarely        310  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df[(df['EducationField'] == 'Technical Degree') & (df['Attrition'] == 'No')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 64     36        No      Travel_Rarely       1223  Research & Development
# 86     23        No      Travel_Rarely        541                   Sales
# 95     54        No      Travel_Rarely       1217  Research & Development
# 117    36        No  Travel_Frequently       1467                   Sales
# 128    22        No      Travel_Rarely        594  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1340   36        No      Travel_Rarely       1266                   Sales
# 1367   27        No      Travel_Rarely       1354  Research & Development
# 1370   47        No         Non-Travel       1169  Research & Development
# 1409   40        No  Travel_Frequently        692  Research & Development
# 1449   32        No      Travel_Rarely        529  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df[(df['Attrition'] == 'Yes') | (df['BusinessTravel'] == 'Non-Travel')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 14     28       Yes      Travel_Rarely        103  Research & Development
# 17     22        No         Non-Travel       1123  Research & Development
# 20     24        No         Non-Travel        673  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1444   56       Yes      Travel_Rarely        310  Research & Development
# 1447   36        No         Non-Travel        301                   Sales
# 1452   50       Yes  Travel_Frequently        878                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.sort_values('Age', ascending=False)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1209   60        No      Travel_Rarely        370  Research & Development
# 411    60        No      Travel_Rarely        422  Research & Development
# 427    60        No  Travel_Frequently       1499                   Sales
# 879    60        No      Travel_Rarely        696                   Sales
# 536    60        No      Travel_Rarely       1179                   Sales
# ...   ...       ...                ...        ...                     ...
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 727    18        No         Non-Travel        287  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# 457    18       Yes  Travel_Frequently       1306                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df1=pd.read_csv("/content/linkedin-reviews.csv")

# %%
df1
# Out:
#                                                 Review  Rating
# 0    Does absolutely nothing for a LinkedIn beginne...       1
# 1                              Force close(galaxy tab)       1
# 2    Slow and it tries to upload your contacts with...       1
# 3    Add ability to customize the profile and move ...       4
# 4    Good app, but it's a pain that it's not possib...       4
# ..                                                 ...     ...
# 697  Can't trust, Going to uninstall just for that ...       1
# 698  It really gets me linked in with my friends. H...       5
# 699  It lacks most of what makes the other social n...       4
# 700  Really disappointed in the new version. Seems ...       2
# 701  One of the best looking and well designed apps...       5
#
# [702 rows x 2 columns]

# %%
df1['Review']
# Out:
# 0      Does absolutely nothing for a LinkedIn beginne...
# 1                                Force close(galaxy tab)
# 2      Slow and it tries to upload your contacts with...
# 3      Add ability to customize the profile and move ...
# 4      Good app, but it's a pain that it's not possib...
#                              ...
# 697    Can't trust, Going to uninstall just for that ...
# 698    It really gets me linked in with my friends. H...
# 699    It lacks most of what makes the other social n...
# 700    Really disappointed in the new version. Seems ...
# 701    One of the best looking and well designed apps...
# Name: Review, Length: 702, dtype: object

# %%
def rating(x):
  if x <= 2:
    return 'Bad'
  elif x == 3:
    return 'Avg'
  else:
    return  'Good'


df1['Rating'] = df1['Rating'].map(rating)

# %%
df1['Rating'].sample()
# Out:
# 196    Avg
# Name: Rating, dtype: object

# %%
bad = df1[df1['Rating'] == 'Bad']

# %%
bad
# Out:
#                                                 Review Rating
# 0    Does absolutely nothing for a LinkedIn beginne...    Bad
# 1                              Force close(galaxy tab)    Bad
# 2    Slow and it tries to upload your contacts with...    Bad
# 5    This app is poor and bad. Linkedin app on my H...    Bad
# 11   Piece of s**t app. Really? You want people to ...    Bad
# ..                                                 ...    ...
# 685                    it's worse than the old one....    Bad
# 686  HATE the new update/layout!!! So hard to look ...    Bad
# 694  Yikes... Talk about losing focus on your targe...    Bad
# 697  Can't trust, Going to uninstall just for that ...    Bad
# 700  Really disappointed in the new version. Seems ...    Bad
#
# [364 rows x 2 columns]

# %%
avg = df1[df1['Rating'] == 'Avg']
good = df1[df1['Rating'] == 'Good']

# %%
avg
# Out:
#                                                 Review Rating
# 9    Clean design with limited features. How about ...    Avg
# 10   App works fine but has limited functionality. ...    Avg
# 12   Simple. Basic. But works perfectly for main fu...    Avg
# 18   Not a bad start, but needs more features like ...    Avg
# 26                                   Wont let you edit    Avg
# ..                                                 ...    ...
# 673    Am not able to add people I find using the app.    Avg
# 680  Application as such ok. But missing possibilit...    Avg
# 689  Thinks there are no discussions in some of my ...    Avg
# 691                              Need to UI attractive    Avg
# 696  Still quite slow and flaky on the Galaxy S, bu...    Avg
#
# [121 rows x 2 columns]

# %%
df=pd.read_csv("/content/covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.sample()
# Out:
#     age  gender  fever cough       city has_covid
# 47   18  Female  104.0  Mild  Bangalore        No

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
len(df[df['has_covid']=='Yes'])
# Out:
# 45

# %%
'''chack missing value
fill mising value
transfor catgorical to numerical with map
based on target columns you have to divid data and perform train test splict'''
# Out:
# 'chack missing value\nfill mising value\ntransfor catgorical to numerical with map\nbased on target columns you have to divid data and perform train test splict'

# %%
df.value_counts()
# Out:
# age  gender  fever  cough   city       has_covid
# 27   Male    100.0  Mild    Delhi      Yes          2
# 5    Female  100.0  Mild    Kolkata    No           1
#      Male    102.0  Mild    Kolkata    Yes          1
# 6    Female  104.0  Mild    Kolkata    Yes          1
# 8    Female  101.0  Mild    Kolkata    No           1
#                                                    ..
# 82   Female  102.0  Strong  Bangalore  No           1
#                             Kolkata    No           1
# 83   Female  101.0  Mild    Kolkata    No           1
#      Male    98.0   Mild    Delhi      Yes          1
#              103.0  Mild    Kolkata    No           1
# Name: count, Length: 89, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df['fever']=df['fever'].fillna(df['fever'].mean())

# %%
df['gender']=df['gender'].map({'Female':0,'Male':1})

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['cough']=df['cough'].map({'Mild':0,'Strong':1})

# %%
df['city']=df['city'].map({'Kolkata':0,'Bangalore':1,'Delhi':2,'Mumbai':3})

# %%
df['has_covid']=df['has_covid'].map({'Yes':0,'No':1})

# %%
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       1  103.0      0     0          1
# 1    27       1  100.0      0     2          0
# 2    42       1  101.0      0     2          1
# 3    31       0   98.0      0     0          1
# 4    65       0  101.0      0     3          1
# ..  ...     ...    ...    ...   ...        ...
# 95   12       0  104.0      0     1          1
# 96   51       0  101.0      1     0          0
# 97   20       0  101.0      0     1          1
# 98    5       0   98.0      1     3          1
# 99   10       0   98.0      1     0          0
#
# [100 rows x 6 columns]

# %%
x=df.drop(columns=['has_covid'])

# %%
from sklearn.model_selection import train_test_split

y = df['has_covid']

x_train, x_test, y_train, y_test = train_test_split(x,
y,
test_size=0.2,
random_state=42)

print(df.shape)
print(x.shape)
print(x_train.shape)
print(x_test.shape)
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (100, 6)
# (100, 5)
# (80, 5)
# (20, 5)
# (100,)
# (80,)
# (20,)

# %%
import seaborn as sns

# %%
x=sns.load_dataset('tips')

# %%
x
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x['sex']=x['sex'].map({'Male':0,'Female':1})
