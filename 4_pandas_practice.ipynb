# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('/content/Attrition - Attrition.csv')
df2 = pd.read_csv('/content/linkedin-reviews - linkedin-reviews (1).csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df2.isnull().sum()
# Out:
# Review    0
# Rating    0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df1['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df1['Attrition'] = df1['Attrition'].map({'Yes':1,'No':2})

# %%
df1.groupby('BusinessTravel').size()
# Out:
# BusinessTravel
# Non-Travel            150
# Travel_Frequently     277
# Travel_Rarely        1043
# dtype: int64

# %%
df1['BusinessTravel'] = df1['BusinessTravel'].map({'Travel_Rarely':1,'Travel_Frequently':2,'Non-Travel':3})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df1.groupby(df1['Department']).size()
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
df1['Department'] = df1['Department'].map({'Sales':1,'Research & Development':2,'Human Resources':3})

# %%
df1.groupby(df1['EducationField']).size()
# Out:
# EducationField
# Human Resources      27
# Life Sciences       606
# Marketing           159
# Medical             464
# Other                82
# Technical Degree    132
# dtype: int64

# %%
df1.drop(columns = ['EducationField'] ,inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int64
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df1.groupby(df1['Gender']).size()
# Out:
# Gender
# Female    588
# Male      882
# dtype: int64

# %%
df1['Gender'] = df1['Gender'].map({'Female':1,'Male':2})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int64
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df1.groupby(df1['JobRole']).size()
# Out:
# JobRole
# Healthcare Representative    131
# Human Resources               52
# Laboratory Technician        259
# Manager                      102
# Manufacturing Director       145
# Research Director             80
# Research Scientist           292
# Sales Executive              326
# Sales Representative          83
# dtype: int64

# %%
df1.drop(columns = ['JobRole'], inplace = True)

# %%
df1.groupby(df1['MaritalStatus']).size()
# Out:
# MaritalStatus
# Divorced    327
# Married     673
# Single      470
# dtype: int64

# %%
df1['MaritalStatus'] = df1['MaritalStatus'].map({'Single':1,'Married':2,'Divorced':3})

# %%
df1.groupby(df1['Over18']).size()
# Out:
# Over18
# Y    1470
# dtype: int64

# %%
(df1['Over18'] == 'Y').count()
# Out:
# np.int64(1470)

# %%
df1['Over18'] = df1['Over18'].map({'Y':1,'N':2})

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   int64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   int64
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EmployeeCount             1470 non-null   int64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   int64
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df1.groupby(df1['OverTime']).size()
# Out:
# OverTime
# No     1054
# Yes     416
# dtype: int64

# %%
df1['OverTime'] = df1['OverTime'].map({'Yes':1,'No':2})

# %%
df1
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               1       1102           1                 1
# 1      49          2               2        279           2                 8
# 2      37          1               1       1373           2                 2
# 3      33          2               2       1392           2                 3
# 4      27          2               1        591           2                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          2               2        884           2                23
# 1466   39          2               1        613           2                 6
# 1467   27          2               1        155           2                 4
# 1468   49          2               2       1023           1                 2
# 1469   34          2               1        628           2                 8
#
# ...

# %%
df1['Gender'].value_counts()
# Out:
# Gender
# 2    882
# 1    588
# Name: count, dtype: int64

# %%
df2
# Out:
#                                                 Review  Rating
# 0    Does absolutely nothing for a LinkedIn beginne...       1
# 1                              Force close(galaxy tab)       1
# 2    Slow and it tries to upload your contacts with...       1
# 3    Add ability to customize the profile and move ...       4
# 4    Good app, but it's a pain that it's not possib...       4
# ..                                                 ...     ...
# 697  Can't trust, Going to uninstall just for that ...       1
# 698  It really gets me linked in with my friends. H...       5
# 699  It lacks most of what makes the other social n...       4
# 700  Really disappointed in the new version. Seems ...       2
# 701  One of the best looking and well designed apps...       5
#
# [702 rows x 2 columns]

# %%
male_y= df1[(df1['Gender'] == 1 & (df1['Attrition'] == 1))]

# %%
female_y = df1[(df1['Gender'] == 2 & (df1['Attrition'] == 1))]

# %%
male_n = df1[(df1['Gender'] == 1 & (df1['Attrition'] == 2))]

# %%
female_n = df1[(df1['Gender'] == 2 ) & (df1['Attrition'] == 2)]

# %%
female_n
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 1      49          2               2        279           2                 8
# 4      27          2               1        591           2                 2
# 5      32          2               2       1005           2                 2
# 7      30          2               1       1358           2                24
# 8      38          2               2        216           2                23
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          2               2        884           2                23
# 1466   39          2               1        613           2                 6
# 1467   27          2               1        155           2                 4
# 1468   49          2               2       1023           1                 2
# 1469   34          2               1        628           2                 8
#
# ...

# %%
male_n
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 3      33          2               2       1392           2                 3
# 6      59          2               1       1324           2                 3
# 11     29          2               1        153           2                15
# 15     29          2               1       1389           2                21
# 18     53          2               1       1219           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1457   40          2               1       1194           2                 2
# 1458   35          2               1        287           2                 1
# 1460   29          2               1        468           2                28
# 1462   39          2               1        722           1                24
# 1464   26          2               1       1167           1                 5
#
# ...

# %%
female # here there is 0 rows because theere is no female with attrition 1
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 33 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  702 non-null    object
#  1   Rating  702 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 11.1+ KB

# %%
def rat(x):
  if x <= 2:
    return 'Bad'
  elif x == 3:
    return 'Avg'
  else:
    return  'Good'


df2['Rating'] = df2['Rating'].map(rat)

# %%
df2['Rating'].sample()
# Out:
# 438    Good
# Name: Rating, dtype: object

# %%
bad = df2[df2['Rating'] == 'Bad']
avg = df2[df2['Rating'] == 'Avg']
good = df2[df2['Rating'] == 'Good']

# %%
bad
# Out:
#                                                 Review Rating
# 0    Does absolutely nothing for a LinkedIn beginne...    Bad
# 1                              Force close(galaxy tab)    Bad
# 2    Slow and it tries to upload your contacts with...    Bad
# 5    This app is poor and bad. Linkedin app on my H...    Bad
# 11   Piece of s**t app. Really? You want people to ...    Bad
# ..                                                 ...    ...
# 685                    it's worse than the old one....    Bad
# 686  HATE the new update/layout!!! So hard to look ...    Bad
# 694  Yikes... Talk about losing focus on your targe...    Bad
# 697  Can't trust, Going to uninstall just for that ...    Bad
# 700  Really disappointed in the new version. Seems ...    Bad
#
# [364 rows x 2 columns]

# %%
good
# Out:
#                                                 Review Rating
# 3    Add ability to customize the profile and move ...   Good
# 4    Good app, but it's a pain that it's not possib...   Good
# 6                                              Finally   Good
# 7    Have been using DroidIn. Ability to move to SD...   Good
# 8                     Works fine on Samsung Captivate.   Good
# ..                                                 ...    ...
# 693  Ok app - needs to be transferable to SD card s...   Good
# 695                  Quick and easy to use. Great app!   Good
# 698  It really gets me linked in with my friends. H...   Good
# 699  It lacks most of what makes the other social n...   Good
# 701  One of the best looking and well designed apps...   Good
#
# [217 rows x 2 columns]

# %%
df=pd.read_csv("/content/linkedin-reviews.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2276569468.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("/content/linkedin-reviews.csv")
#
# NameError: name 'pd' is not defined
